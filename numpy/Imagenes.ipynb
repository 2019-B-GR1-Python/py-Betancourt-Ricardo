# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)

# %%
mapache[::-1]
plt.imshow(mapache[::-1])
plt.show()

# %% [markdown]
# #Quiero dividirle al mapache

# %%
# Quiero hacer 8 piezas con la foto del mapache
arr1, arr2, arr3, arr4, arr5, arr6, arr7, arr8 = np.hsplit(mapache,8)
plt.imshow(arr1)
plt.show()
plt.imshow(arr1)
plt.show()
plt.imshow(arr2)
plt.show()
plt.imshow(arr3)
plt.show()
plt.imshow(arr4)
plt.show()
plt.imshow(arr5)
plt.show()
plt.imshow(arr6)
plt.show()
plt.imshow(arr7)
plt.show()
plt.imshow(arr8)
plt.show()

# %%
# presentar la intensidad de cada  canal  RGB de la imagen
plt.imshow(mapache[:,:,0])
plt.show()
plt.imshow(mapache[:,:,1])
plt.show()
plt.imshow(mapache[:,:,2])
plt.show()

# %%
# sumar un valor  a la matriz del mapache para distorcionar la imagen
plt.imshow(mapache+99)
plt.show()

# %%
# Ver solo el canal de Azul de mi Mapache

mapache_rojo = np.copy(mapache)
mapache_rojo[:,:,0]=0
mapache_rojo[:,:,1]=0

plt.imshow(mapache_rojo)
plt.show()
